# %% [markdown]
# <a href="https://colab.research.google.com/github/hyoje099/mortgages-index/blob/main/%EB%AA%A8%EA%B8%B0%EC%A7%80%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('서울시 모기예보제 정보.csv') as f:
  print(f.readline())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-1-8366ddc01d06> in <cell line: 1>()
#       1 with open('서울시 모기예보제 정보.csv') as f:
# ----> 2   print(f.readline())
#
# /usr/lib/python3.10/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xb8 in position 1: invalid start byte

# %%
import chardet
with open('서울시 모기예보제 정보.csv',mode='rb') as f:
  d = f.readline()
print(chardet.detect(d))
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}

# %%
with open('서울시 모기예보제 정보.csv',encoding='EUC-KR') as f:
  print(f.readline())
  print(f.readline())
# Out:
# "모기지수 발생일","모기지수(수변부)","모기지수(주거지)","모기지수(공원)"
#
# "2024-09-07","100.0","52.0","41.6"

# %%
import pandas as pd

df = pd.read_csv('서울시 모기예보제 정보.csv',encoding='EUC-KR',low_memory=False)
df.head()
# Out:
#      모기지수 발생일  모기지수(수변부)  모기지수(주거지)  모기지수(공원)
# 0  2024-09-07      100.0       52.0      41.6
# 1  2024-09-06      100.0       52.5      51.5
# 2  2024-09-05      100.0       52.0      53.5
# 3  2024-09-04      100.0       51.1      47.5
# 4  2024-09-03      100.0       48.5      47.7

# %%
df.to_csv('ns_202104.csv')

# %%
with open('ns_202104.csv') as f:
  for i in range(3):
    print(f.readline(),end='')
# Out:
# ,모기지수 발생일,모기지수(수변부),모기지수(주거지),모기지수(공원)
# 0,2024-09-07,100.0,52.0,41.6
# 1,2024-09-06,100.0,52.5,51.5

# %%
with open('ns_202104.csv') as f:
  for i in range(3):
    print(f.readline())
# Out:
# ,모기지수 발생일,모기지수(수변부),모기지수(주거지),모기지수(공원)
#
# 0,2024-09-07,100.0,52.0,41.6
#
# 1,2024-09-06,100.0,52.5,51.5

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):
  print(i, end='')
# Out:
# 01234

# %%
ns_df = pd.read_csv('ns_202104.csv',index_col=0,low_memory = False)
ns_df.head()
# Out:
#      모기지수 발생일  모기지수(수변부)  모기지수(주거지)  모기지수(공원)
# 0  2024-09-07      100.0       52.0      41.6
# 1  2024-09-06      100.0       52.5      51.5
# 2  2024-09-05      100.0       52.0      53.5
# 3  2024-09-04      100.0       51.1      47.5
# 4  2024-09-03      100.0       48.5      47.7

# %%
df.to_csv('ns_202104.cvs',index=False)

# %%
df.tail()
# Out:
#         모기지수 발생일  모기지수(수변부)  모기지수(주거지)  모기지수(공원)
# 1605  2016-05-05      243.8      243.8     243.8
# 1606  2016-05-04      256.2      256.2     256.2
# 1607  2016-05-03      304.0      304.0     304.0
# 1608  2016-05-02      273.5      273.5     273.5
# 1609  2016-05-01      254.4      254.4     254.4
